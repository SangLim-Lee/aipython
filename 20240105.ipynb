# %% [markdown]
# <a href="https://colab.research.google.com/github/SangLim-Lee/aipython/blob/main/20240105.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = "John,30,Engineer\nAlice,25,Designer\nBob,22,Artist"
lines = data.split("\n")
for line in lines:
    fields = line.split(",")
    print("Name:", fields[0], "Age:", fields[1], "Occupation:", fields[2])

words = ['Hello', 'world', 'this', 'is', 'a', 'test']
sentence = ' '.join(words)
print(sentence)

squares = [x**2 for x in range(5)]
print(squares)

squares = [x**2 for x in range(5) if x % 2 == 0]
print(squares)


squares = [x**2 for x in range(20) if x % 3 == 0]
print(squares)


squares = [x**2 for x in range(20) if x % 3 == 0 and x != 0]
print(squares)


squares=squares = [x**2 for x in range(6) if x != 0]
print(squares)


input_list = ["Seoul", "New York", "London", "Shanghai", "Paris", "Tokyo"]
output_list = [city for city in input_list if city.startswith('S')]
print(output_list)


fruits = ['apple', 'banana', 'cherry']
for index, fruit in enumerate(fruits):
    print(index, fruit)

fruits = ['a', 'b', 'c']

for index, fruit in enumerate(fruits):
    print(f"fruit{index} name is {fruit}")


fruits = ['a', 'b', 'c']

for index in range(len(fruits)):
    fruit = fruits[index]
    print(f"fruit{index} name is {fruit}")


names = ['John', 'Jane', 'Doe']
ages = [25, 30, 35]
for name, age in zip(names, ages):
    print(f"{name} is {age} years old.")

keys = ['a', 'b', 'c']
values = [1, 2, 3]

my_dict = dict(zip(keys, values))
print(my_dict)



name = ["M", "N", "S", "A"]
roll_no = [4, 1, 3, 2]

result_set = set(zip(name, roll_no))
print(result_set)


names = ['M', 'R', 'C']
ages = [24, 50, 18]

for index, (name, age) in enumerate(zip(names, ages)):
    print(f"{index} {name} {age}")


double = lambda x: x * 2
print(double(5))

def add(x, y):
    return x + y

add_lambda = lambda x, y: x + y
print(add(10,10))


numbers = [1, 2, 3, 4]
squared = list(map(lambda x: x*2, numbers))
print(squared)
# Out:
# Name: John Age: 30 Occupation: Engineer
# Name: Alice Age: 25 Occupation: Designer
# Name: Bob Age: 22 Occupation: Artist
# Hello world this is a test
# [0, 1, 4, 9, 16]
# [0, 4, 16]
# [0, 9, 36, 81, 144, 225, 324]
# [9, 36, 81, 144, 225, 324]
# [1, 4, 9, 16, 25]
# ['Seoul', 'Shanghai']
# 0 apple
# 1 banana
# 2 cherry
# fruit0 name is a
# fruit1 name is b
# fruit2 name is c
# fruit0 name is a
# fruit1 name is b
# fruit2 name is c
# John is 25 years old.
# Jane is 30 years old.
# Doe is 35 years old.
# {'a': 1, 'b': 2, 'c': 3}
# {('N', 1), ('A', 2), ('M', 4), ('S', 3)}
# 0 M 24
# 1 R 50
# 2 C 18
# 10
# 20
# [2, 4, 6, 8]
